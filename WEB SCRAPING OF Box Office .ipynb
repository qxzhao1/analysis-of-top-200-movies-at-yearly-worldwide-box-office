# %% [markdown]
# #  WEB SCRAPING AND DATA CLEANING OF Top 200 Movies at Worldwide Box Office from 2000 to 2017
#  * acquire the data from the box office Mojo
#  * after data cleaning, save it into boxoffice.csv file

# %% [markdown]
# In this part, first we did webscraping to extract the yearly box office data. Then we did data cleaning.

# %% [markdown]
# ### The result of this Step is a CSV file:
#
# * 'boxoffice.csv'

# %%
import pandas as pd
import numpy as np
import urllib.request
from bs4 import BeautifulSoup
import time
import re

# %%
def scrap(year):
    '''
    scarp yearly box office data from boxofficemojo
    input: year, integer number
    output: dataframe of yearly box office information
            colnames=[['Year','Rank', 'Title', 'Studio','Worldwide','Domestic','Overseas','Category','Link']]
            'Link': the movie's web page at mojo
    '''
    url = 'http://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr='+str(year)
    html = urllib.request.urlopen(url)    
    bsObj = BeautifulSoup(html,'lxml-xml')
    
    href_list=bsObj.findAll('a', attrs={'href': re.compile(r"movies")})
    
    Link=[]
    for i in range(1,201):
        m=href_list[i].attrs
        x=str(list(m.values())[0])
        y="http://www.boxofficemojo.com"+x
        z=y.replace('id',r'page=intl&country=CH&id')
        Link.append(z)
        
    td_list=bsObj.find_all('td') 
    data=[]
    for td in td_list:
        l=[]
        for tr in td:
            l.append(tr.string)
        data.append(l)
    
    I = list(range(0,10))
    data=np.delete(data, I).tolist()
    
    Rank=[]
    Title=[]
    Studio=[]
    Worldwide=[]
    Domestic=[]
    Overseas=[]
    for i in range(1599):
        col=i%8
        x=data[i][0]
        if col==0:
            Rank.append(x)
        elif col==1:
            Title.append(x)
        elif col==2:
            Studio.append(x)
        elif col==3:
            Worldwide.append(x)
        elif col==4:
            Domestic.append(x)
        elif col==6:
            Overseas.append(x)
            
    dict={'Rank':Rank,
          'Title':Title,
          'Studio':Studio,
          'Worldwide':Worldwide,
          'Domestic':Domestic,
          'Overseas':Overseas,
          'Link':Link}

    boxoffice = pd.DataFrame(dict)                   
    
    row=boxoffice.shape[0]
    Category=[]
    for i in range(50):
        Category.append("Top1to50")
    for i in range(50,100):
        Category.append("Top51to100")
    for i in range(100,150):
        Category.append("Top101to150")
    for i in range(150,200):
        Category.append("Top151to200")
    boxoffice['Category']=Category
    
    Year=[]
    for i in range(200):
        Year.append(year)
    boxoffice['Year']=Year
    
    boxoffice = boxoffice[['Year','Rank', 'Title', 'Studio','Worldwide','Domestic','Overseas','Category','Link']]
    
    return boxoffice

# %%
def clean(year):
    '''
    clean data 
    input: year, integer number
    output: a tidy dataframe, in which values of the box office are numeric
    '''
    boxoffice=scrap(year)
    row=boxoffice.shape[0]
    
    def Replace(colname):
        '''
        Replace','and '$',and 'k'
        '''

        for i in range(row):
            x=boxoffice[colname][i]
            y=x.replace(',','') 
            z=y.replace('$','')
            boxoffice[colname][i]=z
            if z!="n/a":
                if z.endswith("k"):
                    replace=z.replace('k','')
                    boxoffice[colname][i]=float(float(replace)*0.0100)
        return
    
    Replace("Domestic")
    Replace("Worldwide")
    Replace("Overseas")

    
    #Make sure all columns of numbers are numeric (not strings).
    boxoffice.Worldwide =pd.to_numeric(boxoffice.Worldwide, errors='coerce').fillna(0).astype(float)
    boxoffice.Domestic =pd.to_numeric(boxoffice.Domestic, errors='coerce').fillna(0).astype(float)
    boxoffice.Overseas =pd.to_numeric(boxoffice.Overseas,errors='coerce').fillna(0).astype(float) 
     
    data=boxoffice.round({'Worldwide': 1, 'Domestic': 1,'Overseas':1})
       
    return data

# %%
df=clean(2000)
for i in range(2001,2018):
    i=str(i)
    data=clean(i)
    df=df.append(data, ignore_index=True)
# Out:
# C:\Users\qxzhao\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\qxzhao\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.to_csv('boxoffice.csv',index=False)

# %%
df
# Out:
#       Year Rank                                     Title     Studio  \
# 0     2000    1                    Mission: Impossible II       Par.
# 1     2000    2                                 Gladiator         DW
# 2     2000    3                                 Cast Away        Fox
# 3     2000    4                           What Women Want       Par.
# 4     2000    5                                  Dinosaur         BV
# 5     2000    6            How the Grinch Stole Christmas       Uni.
# 6     2000    7                          Meet the Parents       Uni.
# 7     2000    8                         The Perfect Storm         WB
# 8     2000    9                                     X-Men        Fox
# 9     2000   10                         What Lies Beneath         DW
# 10    2000   11                               Scary Movie      Mira.
# 11    2000   12                          Charlie's Angels       Sony
# 12    2000   13                           Erin Brockovich       Uni.
# 13    2000   14                               Unbreakable         BV
# 14    2000   15                        Gone in 60 Seconds         BV
# 15    2000   16                               Chicken Run         DW
# 16    2000   17                            Vertical Limit       Sony
# 17    2000   18                               The Patriot       Sony
# 18    2000   19            Crouching Tiger, Hidden Dragon        SPC
# 19    2000   20                         Miss Congeniality         WB
# 20    2000   21                                   Traffic        USA
# 21    2000   22                                Hollow Man       Sony
# 22    2000   23                            102 Dalmatians         BV
# 23    2000   24                         Big Momma's House        Fox
# 24    2000   25                  The Emperor's New Groove         BV
# 25    2000   26        The Nutty Professor II: The Klumps       Uni.
# 26    2000   27                                  Scream 3       Dim.
# 27    2000   28                                  Chocolat      Mira.
# 28    2000   29                      Me, Myself and Irene        Fox
# 29    2000   30                                 The Beach        Fox
# ...    ...  ...                                       ...        ...
# 3570  2017  171                                  Ok Jaanu        FIP
# 3571  2017  172    An Inconvenient Sequel: Truth to Power       Par.
# 3572  2017  173                                  Table 19       FoxS
# 3573  2017  174                                   Collide        ORF
# 3574  2017  175                                  The Wall      RAtt.
# 3575  2017  176             Terminator 2: Judgment Day 3D   Distrib.
# 3576  2017  177                            Friend Request      ENTMP
# 3577  2017  178                              Their Finest        STX
# 3578  2017  179                             Brad's Status  Annapurna
# 3579  2017  180                                Raw (2017)        FCW
# 3580  2017  181                                  Colossal       Neon
# 3581  2017  182                               A Gentleman        FIP
# 3582  2017  183                                  Inhumans       Imax
# 3583  2017  184                                      Kedi      Osci.
# 3584  2017  185  Hazlo Como Hombre (Do It Like An Hombre)        PNT
# 3585  2017  186                               Poster Boys       Sony
# 3586  2017  187                              Wonderstruck      RAtt.
# 3587  2017  188                              The Salesman      Cohen
# 3588  2017  189          Pokemon the Movie: I Choose You!     Fathom
# 3589  2017  190                        Jeepers Creepers 3      Scre.
# 3590  2017  191                     Un Padre No Tan Padre        PNT
# 3591  2017  192           The Only Living Boy in New York      RAtt.
# 3592  2017  193                                 Good Time        A24
# 3593  2017  194                  Everybody Loves Somebody        PNT
# 3594  2017  195       Along with the Gods: The Two Worlds      WGUSA
# 3595  2017  196                              Youth (2017)         CL
# 3596  2017  197                           A Quiet Passion       MBox
# 3597  2017  198                                 Free Fire        A24
# 3598  2017  199                             The Last Word        BST
# 3599  2017  200                               Jane (2017)       Abr.
#
#       Worldwide  Domestic  Overseas     Category  \
# 0         546.4     215.4     331.0     Top1to50
# 1         457.6     187.7     269.9     Top1to50
# 2         429.6     233.6     196.0     Top1to50
# 3         374.1     182.8     191.3     Top1to50
# 4         349.8     137.7     212.1     Top1to50
# 5         345.1     260.0      85.1     Top1to50
# 6         330.4     166.2     164.2     Top1to50
# 7         328.7     182.6     146.1     Top1to50
# 8         296.3     157.3     139.0     Top1to50
# 9         291.4     155.5     136.0     Top1to50
# 10        278.0     157.0     121.0     Top1to50
# 11        264.1     125.3     138.8     Top1to50
# 12        256.3     125.6     130.7     Top1to50
# 13        248.1      95.0     153.1     Top1to50
# 14        237.2     101.6     135.6     Top1to50
# 15        224.8     106.8     118.0     Top1to50
# 16        215.7      69.2     146.4     Top1to50
# 17        215.3     113.3     102.0     Top1to50
# 18        213.5     128.1      85.4     Top1to50
# 19        212.7     106.8     105.9     Top1to50
# 20        207.5     124.1      83.4     Top1to50
# 21        190.2      73.2     117.0     Top1to50
# 22        183.6      67.0     116.7     Top1to50
# 23        174.0     117.6      56.4     Top1to50
# 24        169.3      89.3      80.0     Top1to50
# 25        166.3     123.3      43.0     Top1to50
# 26        161.8      89.1      72.7     Top1to50
# 27        152.7      71.5      81.2     Top1to50
# 28        149.3      90.6      58.7     Top1to50
# 29        144.1      39.8     104.3     Top1to50
# ...         ...       ...       ...          ...
# 3570        5.4       3.6       5.0  Top151to200
# 3571        5.4       3.5       1.9  Top151to200
# 3572        5.0       3.6       1.4  Top151to200
# 3573        4.8       2.3       2.5  Top151to200
# 3574        4.5       1.8       2.7  Top151to200
# 3575        3.9       1.0       2.9  Top151to200
# 3576        3.8       3.8       0.0  Top151to200
# 3577        3.6       3.6       0.0  Top151to200
# 3578        3.3       2.1       1.2  Top151to200
# 3579        3.1       5.2       2.6  Top151to200
# 3580        3.0       3.0       0.0  Top151to200
# 3581        2.9       4.1       2.5  Top151to200
# 3582        2.9       1.5       1.3  Top151to200
# 3583        2.8       2.8       0.0  Top151to200
# 3584        2.5       2.5       0.0  Top151to200
# 3585        2.5       1.0       2.4  Top151to200
# 3586        2.5       1.1       1.4  Top151to200
# 3587        2.4       2.4       0.0  Top151to200
# 3588        2.4       2.4       0.0  Top151to200
# 3589        2.3       2.3       0.0  Top151to200
# 3590        2.2       2.2       0.0  Top151to200
# 3591        2.1       6.2       1.5  Top151to200
# 3592        2.0       2.0       0.0  Top151to200
# 3593        1.9       1.9       0.0  Top151to200
# 3594        1.9       1.9       0.0  Top151to200
# 3595        1.9       1.9       0.0  Top151to200
# 3596        1.9       1.9       0.0  Top151to200
# 3597        1.8       1.8       0.0  Top151to200
# 3598        1.8       1.8       0.0  Top151to200
# 3599        1.7       1.7       0.0  Top151to200
#
#                                                    Link
# 0     http://www.boxofficemojo.com/movies/?page=intl...
# 1     http://www.boxofficemojo.com/movies/?page=intl...
# 2     http://www.boxofficemojo.com/movies/?page=intl...
# 3     http://www.boxofficemojo.com/movies/?page=intl...
# 4     http://www.boxofficemojo.com/movies/?page=intl...
